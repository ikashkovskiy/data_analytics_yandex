# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Илья :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Планирование продаж на 2017 для магазина Стримчик

# %% [markdown]
# ## шаг 1

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
#  - [Шаг 2 Подготовка данных](#part_2)
#  - [Шаг 3 Исследовательский анализ данных](#part_3)
#  - [Шаг 4 Портрет пользователя](#part_4)
#  - [Вывод](#sum)
#  - [Шаг 5 Проверка гипотез](#part_5)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, да и самой будет легче идти к главной цели проекта

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import os
from scipy import stats as st
from sklearn import datasets
import seaborn as sns

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />закомментировал код, библиотека не обнаружена
#
#         # import altair as alt

# %%
pth1 = '/Users/ikashkovskiy/Desktop/YANDEX P/data/strimchik/games.csv' 
pth2 = '/datasets/games.csv'

if os.path.exists(pth1):
    df = pd.read_csv(pth1)
elif os.path.exists(pth2):
    df = pd.read_csv(pth2)
else:
    print('Something is wrong')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка проведена корректно
#
# стоит ознакомиться с данными на первом шаге

# %% [markdown]
# ## шаг 2
# #### Подготовка данных
# <a id='part_2'></a>

# %%
df.columns = df.columns.str.lower()
#приводим к нижнему регистру

# %%
df['genre'] = df['genre'].str.lower()
df['name'] = df['name'].str.lower()
df['platform'] = df['platform'].str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит привести к нижнему регистру и содержимое категориальных столбцов, в т.ч. с целью поиска дубликатов

# %%
#проверяем пропущенные значения
# в name, genre и year_of_release нужно убрать пропуски для более информативной статистики
display(df.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
df[df['name'].isnull()]
#2 игры 1993 года, уже не актуальны
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      gen           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      gen           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %%
df = df.dropna(subset = ['name']).reset_index(drop=True)
#df[df['name'].isnull()]
#убираем эти 2 строки

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> скажи пожалуйста, нам нужны две очень-очень старые игры для решения главной задачи проекта?

# %%
#удаляем игры без года выпуска, их меньше 2%
df = df.dropna(subset = ['year_of_release']).reset_index(drop=True)
#округляем
df['year_of_release'] = np.ceil(df['year_of_release'])
#df[df['year_of_release'].isnull()]

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты проделал большую работу по восстановлению пропусков. Но такую долю пропусков вряд ли можно корректно восстановить по имеющимся значениям
#
# к тому же их актуальность вызывает сомнение
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
df['user_score'].sort_values().unique()
#tbd = to be decided or to be determined: used when something has not yet been decided or is not yet known
#рейтинг еще не определен, заполним NAN
df['user_score'] = df['user_score'].replace("tbd", np.NaN)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
df = df.astype({'year_of_release': np.int64, 'user_score': 'float64'})

# %%
#добавляем столбец с суммой продаж
df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты проделал большую работу по восстановлению пропусков. Но такую долю пропусков вряд ли можно корректно восстановить по имеющимся значениям

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты проделал большую работу по восстановлению пропусков. Но такую долю пропусков вряд ли можно корректно восстановить по имеющимся значениям

# %%
#проверяем на дубликаты
df.duplicated().sum()
# Out:
# 0

# %%
# check
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           9768 non-null   object
#  11  total_sales      16444 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Рейтинг — категориальные данные, стоит внимательно взглянуть на содержимое и предложить чем заполнить пропуски, возможно это поможет найти необычные различия в поведении клиентов, допом можно подумать над сокращением количества категорий
#
# Т.к. записи с пропусками не учитываются при группировке данных, мы не сможем выявить реальный портрет клиента

# %% [markdown]
# ## итоги по шагу 2

# %% [markdown]
#  #### подготовил данные:
#  - заменил пропуски в столбце year_of_release на медиану по платформе (удалялть более 250 строк нецелесообразно)
#  - сменил типы данных у двух стодбцов для упрощения дальнейщего анализа
#  - добавил столбец с суммой продаж по регионам
#  - привел названия столбцов к нижнему регистру
#  - заменил пропушенные значения оценок критиков и пользователей медианами в зависимости от платформы  и продаж

# %% [markdown]
# ## шаг 3
# #### исследовательский анализ данных
# <a id='part_3'></a>

# %%
#таблица с количеством игр по платформам и годам, не очень информативная
df_game_sum = (df.pivot_table(index=['platform','year_of_release'],
                             values=['name'],
                             aggfunc = {'name':'count'}))

df_game_sum
# Out:
#                           name
# platform year_of_release
# 2600     1980                9
#          1981               46
#          1982               36
#          1983               11
#          1984                1
# ...                        ...
# xb       2008                1
# xone     2013               19
#          2014               61
#          2015               80
#          2016               87
#
# [238 rows x 1 columns]

# %%
df_test = df.query('platform == "ds" and year_of_release == 1985')
df_test
# Out:
#                                       name platform  year_of_release   genre  \
# 15704  strongest tokyo university shogi ds       ds             1985  action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15704       0.0       0.0      0.02          0.0           NaN         NaN
#
#       rating  total_sales
# 15704    NaN         0.02

# %%
df.drop(labels = [15704],axis = 0, inplace = True)
#df_test

# %%
#построим тепловую карту для определния жизненого цикла платформ 
df_heatmap=df.pivot_table(index="platform",columns='year_of_release',values='name',
                             aggfunc = {'name':'count'})
f, ax = plt.subplots(figsize=(17,17))
sns.set_theme()
sns.heatmap(df_heatmap, linewidths=.5)
plt.title("Количество игр в год по платформам")
plt.xlabel("Годы")
plt.ylabel("Платформы")
# Out:
# Text(133.0, 0.5, 'Платформы')

# %% [markdown]
#  - По данным тепловой карты можно сделать вывод, о том что платформы (кроме ПК) обычно являются популярными около 10 лет, далее их заменяет более продвинутая модель (прим. XB - XB360 - XOne или PS - PS2 - PS3 - PS4)
#  - Так же видно количество игр выпущенных для различных платформ

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />интересное оформление тепловой карты, молодец,
#
# считать только приходиться вручную ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года, у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить (может повлиять на расчет среднего срока актуальности платформ)
#
#
# <br />
#     <font size="3", color = "black">
# <br />
#  - Да, такой игры в интернете не нашел..   И удалил

# %%
#график выхода игр по годам для всех платформ
#видно что после 2000 года начался резкий рост производства игр
df.pivot_table(index='year_of_release', values='name', aggfunc={'name':'count'}).plot(grid=True, figsize=(16, 7))
plt.title("Количество игр по годам")
plt.xlabel("Год выпуска")
plt.ylabel("Количество выпущенных игр")
plt.legend()

# %% [markdown]
#  - Рост выпуск игр начался в 2000х годах, пик пришелся на 2009, далее наметился спад

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец

# %%
#список 5 самых прибыльных платформ за все время
platforms_top = df.groupby('platform')['total_sales'].sum().sort_values()[-5:].index.tolist()
platforms_top
# Out:
# ['ds', 'wii', 'ps3', 'x360', 'ps2']

# %% [markdown]
#  - Проверим данные для основных платформ

# %%
df_new_releases = df.query('year_of_release >= 2013')

# %%
#собрал список актуальных платформ
platforms_top_new = df_new_releases.groupby('platform')['total_sales'].sum().sort_values()[-6:].index.tolist()
platforms_top_new
# Out:
# ['wiiu', 'x360', '3ds', 'xone', 'ps3', 'ps4']

# %%
df_new_releases = df.query('year_of_release >= 2013 and platform == @platforms_top_new')

# %%
#создал датафрейм с актуальными платформами и заменил названия отсальных платформ на 'other'
df_new_releases_other = df.query('year_of_release >= 2013 and platform != @platforms_top_new')
df_new_releases_other.loc[:,'platform'] = 'other'
df_new_releases = df_new_releases.append(df_new_releases_other)
# Out:
# /Users/ikashkovskiy/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
#на графике видно, что продажи уже идут на спад, но ps4 и xone еще "протянут" несколько лет до смены поколения платформ
df_new_releases.pivot_table('total_sales', index='year_of_release', columns='platform', aggfunc='sum').plot(figsize=(17,7))
plt.title("Выручка в год по платформам с 2013 года")
plt.xlabel("Платформы")
plt.ylabel("Годы")
# Out:
# Text(0, 0.5, 'Годы')

# %%
df_new_releases.pivot_table('name', index='year_of_release', columns='platform', aggfunc={'name':'count'}).plot(figsize=(17,7))
plt.title("Выпущенные игры в год по платформам с 2013 года")
plt.xlabel("Годы")
plt.ylabel("Количество выпущенных игр")
# Out:
# Text(0, 0.5, 'Количество выпущенных игр')

# %% [markdown]
#  - срез по платформам, которые являются лидирующими по продажам с 2013 года
#  - на основе графиков виден общий тренд на дальнейщее снижение выручки от продажи игр на основных платформах 2013-2016 годов
#  - но в то же время колличество выпускаемых игр на ps4 и xone увеличивается - эти платформы еще будут актуальны

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды
#
#         - сделал срез по более актуальным данным по играм с 2013 года

# %%
sales_on_platform = df_new_releases.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False)

plt.figure(figsize=(16,7))
sns.barplot(x=sales_on_platform.index, y=sales_on_platform['total_sales'])
plt.title("Продажи по основным платформам после 2013")
plt.xlabel("Название платформы")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %%
#sales_on_platform.head()

# %%
#Построил график «ящик с усами» по глобальным продажам игр в разбивке по платформам 
plt.figure(figsize=(17,10))
plt.ylim(0,4)
sns.boxplot(x='platform',y='total_sales',data=df_new_releases)
plt.title("Распределение продаж по основным платформам после 2005")
plt.xlabel("Название платформы")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %%
plt.figure(figsize=(17,10))
sns.boxplot(x='platform',y='total_sales',data=df_new_releases)
plt.title("Распределение продаж по основным платформам после 2005")
plt.xlabel("Название платформы")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %% [markdown]
#  - медианы на стационарных консолях схожи, медианы на портативных консолях так же схожи. Продажи на ПК низкие скорее всего потому что для ПК делают мало игр.
#  - Все диаграммы скошены вправо
#  - Судя по выбросам ps3 и x360, остальным платформам есть куда расти
#  - В "other" собрал не вошедшие в рейтинг платформы - (прим. PC и др)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Стоит добавить второй вид диаграммы размаха, со всеми выбросами, это наши рекордсмены по выручке :)
#
#         - добавил

# %%
#создадим отдельный датафрейм для анализа корреляции с ps3
df_ps3 = df.query('platform == "ps3"')
#df_ps3
sns.relplot(x="critic_score", y="total_sales", data=df_ps3)
sns.relplot(x="user_score", y="total_sales", data=df_ps3)

# %%
#создадим отдельный датафрейм для анализа корреляции с ps4
df_ps4 = df.query('platform == "ps4"')
#df_ps3
sns.relplot(x="critic_score", y="total_sales", data=df_ps4)
sns.relplot(x="user_score", y="total_sales", data=df_ps4)

# %%
#создадим отдельный датафрейм для анализа корреляции с x360
df_x360 = df.query('platform == "x360"')
#df_ps3
sns.relplot(x="critic_score", y="total_sales", data=df_x360)
sns.relplot(x="user_score", y="total_sales", data=df_x360)

# %%
#создадим отдельный датафрейм для анализа корреляции с xone
df_xone = df.query('platform == "xone"')
#df_ps3
sns.relplot(x="critic_score", y="total_sales", data=df_xone)
sns.relplot(x="user_score", y="total_sales", data=df_xone)

# %%
print('корреляция отзывов критиков и продаж равна =', df['total_sales'].corr(df['critic_score']))
print('корреляция отзывов пользователей и продаж равна =', df['total_sales'].corr(df['user_score']))
# Out:
# корреляция отзывов критиков и продаж равна = 0.24534884547411376
# корреляция отзывов пользователей и продаж равна = 0.08798399271321643

# %%
print('корреляция отзывов критиков и продаж на платформе PS3 равна =',
      df_ps3['total_sales'].corr(df_ps3['critic_score']))
print('корреляция отзывов пользователей и продаж на платформе PS3 равна =',
      df_ps3['total_sales'].corr(df_ps3['user_score']))
# Out:
# корреляция отзывов критиков и продаж на платформе PS3 равна = 0.4327589578997134
# корреляция отзывов пользователей и продаж на платформе PS3 равна = 0.12841562938563028

# %%
print('корреляция отзывов критиков и продаж на платформе PS4 равна =',
      df_ps4['total_sales'].corr(df_ps4['critic_score']))
print('корреляция отзывов пользователей и продаж на платформе PS4 равна =',
      df_ps4['total_sales'].corr(df_ps4['user_score']))
# Out:
# корреляция отзывов критиков и продаж на платформе PS4 равна = 0.406567902061781
# корреляция отзывов пользователей и продаж на платформе PS4 равна = -0.031957110204556424

# %%
print('корреляция отзывов критиков и продаж на платформе X360 равна =',
      df_x360['total_sales'].corr(df_x360['critic_score']))
print('корреляция отзывов пользователей и продаж на платформе X360 равна =',
      df_x360['total_sales'].corr(df_x360['user_score']))
# Out:
# корреляция отзывов критиков и продаж на платформе X360 равна = 0.39286589254006987
# корреляция отзывов пользователей и продаж на платформе X360 равна = 0.11418661214018049

# %%
print('корреляция отзывов критиков и продаж на платформе XOne равна =',
      df_xone['total_sales'].corr(df_xone['critic_score']))
print('корреляция отзывов пользователей и продаж на платформе XOne равна =',
      df_xone['total_sales'].corr(df_xone['user_score']))
# Out:
# корреляция отзывов критиков и продаж на платформе XOne равна = 0.41699832800840175
# корреляция отзывов пользователей и продаж на платформе XOne равна = -0.06892505328279412

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит добавить в проект — исследование зависимости по платформам конкурентам, отдельно две-три платформы
#
#         пункт задания "Соотнесите выводы с продажами игр на других платформах."
#
# Выводы, сделанные на основе расчетов по нескольким платформам выглядят "весомей" и убедительней

# %% [markdown]
#  - Корреляция продаж и отзывов критиков присутствует, но полагаться на нее не стоит
#  - В то же время корреляция продаж и отзывов пользователей очень низкая и в случаях с актуальными платформами - отрицательная

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#     Корреляция продаж и отзывов критиков заметно выше чем зависимость от оценки пользователей
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %%
#продажи по жанрам за все время
sales_by_genre = df.pivot_table(index='genre', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False)

plt.figure(figsize=(16,7))
sns.barplot(x=sales_by_genre.index, y=sales_by_genre['total_sales'])
plt.title("Продажи по жанрам")
plt.xlabel("Название жанра")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %%
#продажи по жанрам после 2005
sales_by_genre = df_new_releases.pivot_table(index='genre', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False)

plt.figure(figsize=(16,7))
sns.barplot(x=sales_by_genre.index, y=sales_by_genre['total_sales'])
plt.title("Продажи по жанрам")
plt.xlabel("Название жанра")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %%
df_heatmap=df_new_releases.pivot_table(index="platform",columns='genre',values='name',
                             aggfunc = {'name':'count'})
f, ax = plt.subplots(figsize=(17,7))
sns.set_theme()
sns.heatmap(df_heatmap, linewidths=.5)
plt.title("Количество выпущенных игр по жанрам на актуальных платформах")
plt.xlabel("Жанры")
plt.ylabel("Платформы")
# Out:
# Text(129.5, 0.5, 'Платформы')

# %% [markdown]
#  - Самые популярные игры в жанрах Action, RPG, Shooter, Sport и Misc
#  - Топ 5 жанров практически не извменились, только Shooter стал более прибыльным и обощел Sport
#  - Самое большое колличество игр выпушено в жанрах Action, RPG, Adventure

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# ## Шаг 4. Составьте портрет пользователя каждого региона
# <a id='part_4'></a>

# %%
df_by_area_plot = df_new_releases.pivot_table(index='platform',
                                                     values=['na_sales', 'other_sales',
                                                    'eu_sales', 'jp_sales'],aggfunc=('sum'))
df_by_area_plot.plot(kind="bar", figsize=(17,7))
# Out:
# <AxesSubplot:xlabel='platform'>

# %%
#сделаем срез продаж по платформах в разных регионах
df_by_area=df.pivot_table(index='platform',values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'],aggfunc=('sum'))
df_by_area=df_by_area.sort_values(by='total_sales',ascending=False).head(10)
df_by_area
# Out:
#           eu_sales  jp_sales  na_sales  other_sales  total_sales
# platform
# ps2         332.63    137.54    572.92       190.47      1233.56
# x360        268.32     12.30    595.74        84.88       961.24
# ps3         327.21     79.41    390.13       134.59       931.34
# wii         258.32     68.28    486.87        77.71       891.18
# ds          188.41    175.00    380.31        59.04       802.76
# ps          212.39    139.78    334.72        40.69       727.58
# ps4         141.09     15.96    108.74        48.35       314.14
# gba          74.59     46.56    184.12         7.61       312.88
# psp          65.62     75.88    107.27        40.76       289.53
# 3ds          61.27    100.62     82.65        13.27       257.81

# %%
#сравним с показателями последних 3 лет
df_by_area=df_new_releases.pivot_table(index='platform',values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'],aggfunc=('sum'))
df_by_area=df_by_area.sort_values(by='total_sales',ascending=False).head(10)
df_by_area
# Out:
#           eu_sales  jp_sales  na_sales  other_sales  total_sales
# platform
# ps4         141.09     15.96    108.74        48.35       314.14
# ps3          67.81     23.35     63.50        26.77       181.43
# xone         51.59      0.34     93.12        14.27       159.32
# 3ds          30.96     67.81     38.20         6.28       143.25
# x360         42.52      0.51     81.66        12.11       136.80
# other        38.41     21.93     23.28         7.50        91.12
# wiiu         19.85     10.88     29.21         4.69        64.63

# %% [markdown]
#  - Основные отличия между регионами по платформам:
#    - в Японии портативные консоли заметно популярнее чем в других регионах
#    - в Японии не популярны изры на ПК и зарубежных консолях (XBOX)
#    - Северная Америка и Европа сходятся в предпочтениях
#    - "другие" платформы так же занимают значимую долю продаж

# %%
#сделаем срез продаж по жанрам в разных регионах
df_by_area=df.pivot_table(index='genre',values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'],aggfunc=('sum'))
df_by_area=df_by_area.sort_values(by='total_sales',ascending=False).head(5)
df_by_area
# Out:
#               eu_sales  jp_sales  na_sales  other_sales  total_sales
# genre
# action          510.99    160.12    863.17       182.22      1716.50
# sports          371.33    134.93    671.20       132.21      1309.67
# shooter         314.52     38.68    584.83       103.33      1041.36
# role-playing    188.24    353.39    330.04        59.41       931.08
# platform        199.39    130.71    444.44        51.01       825.55

# %%
#сравним с продажами с 2013 года
df_by_area=df_new_releases.pivot_table(index='genre',values=['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'],aggfunc=('sum'))
df_by_area=df_by_area.sort_values(by='total_sales',ascending=False).head(5)
df_by_area
# Out:
#               eu_sales  jp_sales  na_sales  other_sales  total_sales
# genre
# action          118.13     40.49    126.05        37.20       321.87
# shooter          87.86      6.61    109.74        28.77       232.98
# sports           60.52      5.41     65.27        19.45       150.65
# role-playing     36.97     51.04     46.40        11.48       145.89
# misc             20.04      9.20     27.49         6.09        62.82

# %%
#сделаем более наглядную инфографику по продажам жанров в разных регионах с 2013
df_by_area_plot = df_new_releases.pivot_table(index='genre',
                                                     values=['na_sales', 'other_sales',
                                                    'eu_sales', 'jp_sales'],aggfunc=('sum'))
df_by_area_plot.plot(kind="bar", figsize=(17,7))
# Out:
# <AxesSubplot:xlabel='genre'>

# %% [markdown]
#  - Основные отличия между регионами по жанрам:
#    - в Японии RPG игры заметно популярнее чем в других регионах и занимают 1 место по продажам
#    - в Японии менее популярны игры в жанрах Sport, Shooter, Action, Racing (скорее всего из-за распространения портативных консолей, для которых выпускаются отдельные игры)
#    - Северная Америка и Европа сходятся в предпочтениях почти во всем

# %%
fig, axes = plt.subplots(1, 4, figsize=(17, 5))
plt.suptitle("Продажи в разных регионах по платформам")
plt.subplot(1, 4, 1)
plt.plot(df_new_releases['na_sales'], df_new_releases['platform'], 'o')  
plt.title("Северная Америка")
plt.xlabel("Продажи")
plt.ylabel("Платформы")

plt.subplot(1, 4, 2)
plt.plot(df_new_releases['eu_sales'], df_new_releases['platform'], 'o')
plt.title("Европа")
plt.xlabel("Продажи")
plt.subplot(1, 4, 3)

plt.plot(df_new_releases['jp_sales'], df_new_releases['platform'], 'o')
plt.title("Япония")
plt.xlabel("Продажи")

plt.subplot(1, 4, 4)
plt.plot(df_new_releases['other_sales'], df_new_releases['platform'], 'o')
plt.title("Другие Страны")
plt.xlabel("Продажи")
# Out:
# Text(0.5, 0, 'Продажи')

# %%
fig, axes = plt.subplots(1, 4, figsize=(17, 5))
plt.suptitle("Продажи в разных регионах по годам")
plt.subplot(1, 4, 1)
plt.plot(df_new_releases['na_sales'], df_new_releases['year_of_release'], 'o')  
plt.title("Северная Америка")
plt.xlabel("Продажи")
plt.ylabel("Годы")

plt.subplot(1, 4, 2)
plt.plot(df_new_releases['eu_sales'], df_new_releases['year_of_release'], 'o')
plt.title("Европа")
plt.xlabel("Продажи")
plt.subplot(1, 4, 3)

plt.plot(df_new_releases['jp_sales'], df_new_releases['year_of_release'], 'o')
plt.title("Япония")
plt.xlabel("Продажи")

plt.subplot(1, 4, 4)
plt.plot(df_new_releases['other_sales'], df_new_releases['year_of_release'], 'o')
plt.title("Другие Страны")
plt.xlabel("Продажи")
# Out:
# Text(0.5, 0, 'Продажи')

# %%
fig, axes = plt.subplots(1, 4, figsize=(17, 5))
plt.suptitle("Продажи в разных регионах по жанрам")
plt.subplot(1, 4, 1)
plt.plot(df_new_releases['na_sales'], df_new_releases['genre'], 'o')  
plt.title("Северная Америка")
plt.xlabel("Продажи")
plt.ylabel("Жанры")

plt.subplot(1, 4, 2)
plt.plot(df_new_releases['eu_sales'], df_new_releases['genre'], 'o')
plt.title("Европа")
plt.xlabel("Продажи")
plt.subplot(1, 4, 3)

plt.plot(df_new_releases['jp_sales'], df_new_releases['genre'], 'o')
plt.title("Япония")
plt.xlabel("Продажи")

plt.subplot(1, 4, 4)
plt.plot(df_new_releases['other_sales'], df_new_releases['genre'], 'o')
plt.title("Другие Страны")
plt.xlabel("Продажи")
# Out:
# Text(0.5, 0, 'Продажи')

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов рассчитаны и отрисованы, молодец, сильное влияние на портрет оказывает период с 2005 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/?ysclid=l4q3l4q0p8940570437
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html?highlight=append#pandas.DataFrame.append

# %%
df['rating'] = df['rating'].fillna('without_rating')

# %%
df_by_rating=df.pivot_table(index='rating',values=['na_sales', 'eu_sales',
                                                   'jp_sales', 'other_sales',
                                                   'total_sales'],aggfunc=('sum'))
df_by_rating=df_by_rating.sort_values(by='total_sales',ascending=False)
df_by_rating
# Out:
#                 eu_sales  jp_sales  na_sales  other_sales  total_sales
# rating
# without_rating    609.65    836.72   1225.84       149.87      2822.08
# E                 703.87    197.96   1274.24       231.54      2407.61
# T                 421.79    150.70    747.60       152.99      1473.08
# M                 480.00     63.58    742.89       176.06      1462.53
# E10+              183.35     40.20    345.50        71.93       640.98
# K-A                 0.27      1.46      2.56         0.03         4.32
# AO                  0.61      0.00      1.26         0.09         1.96
# EC                  0.11      0.00      1.53         0.11         1.75
# RP                  0.03      0.00      0.00         0.01         0.04

# %%
df_by_rating=df_new_releases.pivot_table(index='rating',values=['na_sales', 'eu_sales',
                                                   'jp_sales', 'other_sales',
                                                   'total_sales'],aggfunc=('sum'))
df_by_rating=df_by_rating.sort_values(by='total_sales',ascending=False)
df_by_rating
# Out:
#         eu_sales  jp_sales  na_sales  other_sales  total_sales
# rating
# M         145.32     14.11    165.21        47.04       371.68
# E          83.36     15.14     79.05        22.61       200.16
# T          41.95     20.59     49.79        14.29       126.62
# E10+       42.69      5.89     54.24        12.57       115.39

# %% [markdown]
#  - Получается что игр "без рейтинга" к 2013 году не осталось (рейтинги ввели в 1994 году)
#  - Последние 3 года по общим продажам преобладают игры для взрослых, за счет Европы, Северной Америки и других стран
#  - Японцы же предпочитают игры для тинейджеров и "для всех возрастов"

# %%
df_by_area_plot = df.pivot_table(index='rating',values=['na_sales', 'other_sales',
                                                    'eu_sales', 'jp_sales'],aggfunc=('sum'))
df_by_area_plot.plot(kind="bar", figsize=(17,7))

#продажи за все время по рейтингам
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
df_by_rating=df_new_releases.pivot_table(index=['name', 'platform',
                                   'genre', 'year_of_release', 'rating',
                                    'critic_score', 'user_score'],
                            values=['jp_sales','total_sales'],aggfunc=('sum'))
df_by_rating=df_by_rating.sort_values(by='jp_sales',ascending=False).head()
df_by_rating
# Out:
#                                                                                                            jp_sales  \
# name                                 platform genre        year_of_release rating critic_score user_score
# monster hunter 4 ultimate            3ds      role-playing 2014            T      86.0         8.7             2.62
# splatoon                             wiiu     shooter      2015            E10+   81.0         8.5             1.46
# animal crossing: happy home designer 3ds      simulation   2015            E      66.0         6.9             1.40
# mario kart 8                         wiiu     racing       2014            E      88.0         9.1             1.28
# luigi's mansion: dark moon           3ds      action       2013            E      86.0         8.4             1.11
#
#                                                                                                            total_sales
# ...

# %%
df_by_rating=df_new_releases.pivot_table(index=['name', 'platform',
                                   'genre', 'year_of_release', 'rating',
                                    'critic_score', 'user_score']
                                    ,values=['na_sales', 'total_sales'],aggfunc=('sum'))
df_by_rating=df_by_rating.sort_values(by='na_sales',ascending=False).head()
df_by_rating
# Out:
#                                                                                       na_sales  \
# name                 platform genre   year_of_release rating critic_score user_score
# grand theft auto v   x360     action  2013            M      97.0         8.1             9.66
#                      ps3      action  2013            M      97.0         8.2             7.02
# call of duty: ghosts x360     shooter 2013            M      73.0         2.6             6.73
#                      ps3      shooter 2013            M      71.0         2.6             4.10
# grand theft auto v   ps4      action  2014            M      97.0         8.3             3.96
#
#                                                                                       total_sales
# name                 platform genre   year_of_release rating critic_score user_score
# grand theft auto v   x360     action  2013            M      97.0         8.1               16.27
# ...

# %%
df_by_rating=df_new_releases.pivot_table(index=['name', 'platform',
                                   'genre', 'year_of_release', 'rating',
                                    'critic_score', 'user_score'],
                                    values=['eu_sales','total_sales'],aggfunc=('sum'))
df_by_rating=df_by_rating.sort_values(by='eu_sales',ascending=False).head()
df_by_rating
# Out:
#                                                                                    eu_sales  \
# name               platform genre  year_of_release rating critic_score user_score
# grand theft auto v ps3      action 2013            M      97.0         8.2             9.09
#                    ps4      action 2014            M      97.0         8.3             6.31
# fifa 16            ps4      sports 2015            E      82.0         4.3             6.12
# fifa 17            ps4      sports 2016            E      85.0         5.0             5.75
# grand theft auto v x360     action 2013            M      97.0         8.1             5.14
#
#                                                                                    total_sales
# name               platform genre  year_of_release rating critic_score user_score
# grand theft auto v ps3      action 2013            M      97.0         8.2               21.05
# ...

# %% [markdown]
# <a id='sum'></a>
#
# Итог:
#    - Актуальные платформы:
#        - Северная Америка: ps4, x0ne, wiiu
#        - Европа: ps4, ps3, x0ne, wiiu
#        - Япония: 3ds, ps4, wiiu
#        - Другие страны:  ps4, ps3, x360, wiiu
#    - Актуальные жанры:
#        - Северная Америка: action, shooter, sport
#        - Европа: action, shooter, sport
#        - Япония: RPG, action, misc
#        - Другие страны:  action, shooter, sport
#    - Основные рейтинги ESRB:
#        - Северная Америка: M, E, E10+
#        - Европа: M, E, E10+
#        - Япония: T, E, M
#        - Другие страны:  M, E, T
#
#    - Лучше всего будут продаваться игры для всех возрастов и для взрослых
#    - Пользователи скорее предпочтут игру с высокими оценками критиков
#    - Самыми актальными жанрами будут Action, Sport, Shooter, Role-Playing, так же не стоит забывать Platform и Misc
#      игры, которые выпускают до сих пор.
#    - Стоит сконцентрироваться на актуальных платформах: '3DS','PS4','XOne' и 'Wiiu'
#    - Стоит обратить внимание на популярные ежегодные серии игр (прим. FIFA)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Вывод составлен грамотно, стоит подправить после исправления всех комментариев
#
# очепятка
#
#         Стоит сконцентрироваться на актуальных платформах '3DS','PS4','XOne' и 'Wii', но возможно появление новых

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# ## Шаг 5
#
# <a id='part_5'></a>

# %%
df_x_one=df.query('platform == "xone" and year_of_release >= 2013 and critic_score >= 0')
df_pc=df.query('platform == "pc" and year_of_release >= 2013 and critic_score >= 0')

#Гипотеза 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые 
# H0 - Средние пользовательские рейтинги равны, Н1 - Средние пользовательские рейтинги не равны

xone_ttest = df_x_one['critic_score']

pc_ttest = df_pc['critic_score']

alpha = .05

results = st.ttest_ind(xone_ttest, pc_ttest, equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Средние пользовательские рейтинги не равны")
else:
    print("Средние пользовательские рейтинги равны")
# Out:
# p-значение: 0.09210180347405479
# Средние пользовательские рейтинги равны

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> гипотезы сформулированы верно

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />интересно узнать степень влияния на результаты стат. теста — от заполнения пропусков в колонке оценки пользователей

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...

# %% [markdown]
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») за определенный период времени и без учета игр без рейтинга равны.

# %%
df_action=df.query('genre == "action" and user_score >= 0')
df_sports=df.query('genre == "sports"and user_score >= 0')


#Гипотеза 2. Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) 
#и Sports (англ. «спортивные соревнования») разные. 
# H0 - Средние пользовательские рейтинги равны, Н1 - Средние пользовательские рейтинги не равны

action_ttest = df_action['user_score']

sports_ttest = df_sports['user_score']

alpha = .05

results = st.ttest_ind(action_ttest, sports_ttest, equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Средние пользовательские рейтинги не равны")
else:
    print("Средние пользовательские рейтинги равны")
# Out:
# p-значение: 0.07370217419278534
# Средние пользовательские рейтинги равны

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Нулевая и альтернативная гипотезы сформулированы не корректно
#
#         # H0 - Средние пользовательские рейтинги разные, Н1 - Средние пользовательские рейтинги одинаковые

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.24325665259281073

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Оформление вывода: стоит кратко напомнить цель исследования, как мы его провели, какие параметры рассматривали, какие редкие и выбивающиеся значения убрали, какие особенности и инсайты в данных нашли (упоминаем только основные 3-5,  с приведением найденных числовых значений), выделяем сильные корреляционные связи на парных признаках, если они есть
#
# Не забываем формировать перечень рекомендаций для выбора конкретной платформы, жанра, рейтинга  для рекламной кампании 2017 года для каждого региона
#
#
# Минимальный объем для вывода это 3-4 абзаца, оптимальный 10-12, в т.ч. можно включать все промежуточные выводы

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить название
#  + 2 старые игры
#  + обработка пропусков в столбце рейтингов
#  + сократить категории в рейтингах — на твое усмотрение
#  + самое важное — переопределить актуальный период
#
#  + добавить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#
#  + оценить прибыльность жанров на диаграмме размаха
#  + построить графики в ТОП-5 и пересмотреть раздел рейтингов
#  + в разделе проверки гипотез подправить выборки плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные  выводы после всех исправлений
#  + сформировать итоговый вывод
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
